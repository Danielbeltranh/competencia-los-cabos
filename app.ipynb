# %%
# %pip install streamlit folium pandas
# Out:
# Requirement already satisfied: streamlit in /Users/danib/anaconda3/lib/python3.11/site-packages (1.48.0)
# Requirement already satisfied: folium in /Users/danib/anaconda3/lib/python3.11/site-packages (0.19.5)
# Requirement already satisfied: pandas in /Users/danib/anaconda3/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: numpy<3,>=1.23 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<26,>=20 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (23.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (6.31.1)
# Requirement already satisfied: pyarrow>=7.0 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (4.14.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /Users/danib/anaconda3/lib/python3.11/site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: branca>=0.6.0 in /Users/danib/anaconda3/lib/python3.11/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /Users/danib/anaconda3/lib/python3.11/site-packages (from folium) (3.1.2)
# Requirement already satisfied: xyzservices in /Users/danib/anaconda3/lib/python3.11/site-packages (from folium) (2022.9.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/danib/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/danib/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: jsonschema>=3.0 in /Users/danib/anaconda3/lib/python3.11/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: narwhals>=1.14.2 in /Users/danib/anaconda3/lib/python3.11/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/danib/anaconda3/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/danib/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: six>=1.5 in /Users/danib/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/danib/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/danib/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/danib/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/danib/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/danib/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: attrs>=17.4.0 in /Users/danib/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/danib/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.18.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import streamlit as st
import folium
from folium.plugins import MarkerCluster
from io import StringIO

st.set_page_config(page_title="Mapa Competencia Los Cabos", layout="wide")

# --- carga de datos ---
df = pd.read_csv("competencia_los_cabos.csv")

# normalizar campos de filtros
def split_tags(x):
    if not isinstance(x, str) or not x.strip():
        return []
    # separa por coma/;/| y limpia espacios
    raw = [t.strip() for t in x.replace("|", ",").replace(";", ",").split(",")]
    return [t for t in raw if t]

df["amenidades_tags"] = df["amenidades"].apply(split_tags)
for col in ["tipo_desarrollo", "diseno_estilo", "estado_desarrollo"]:
    df[col] = df[col].fillna("").astype(str).str.strip()

# opciones de filtros
amenities_all = sorted({a for lst in df["amenidades_tags"] for a in lst})
tipos_all      = sorted([t for t in df["tipo_desarrollo"].unique() if t])
estilos_all    = sorted([t for t in df["diseno_estilo"].unique() if t])
estados_all    = sorted([t for t in df["estado_desarrollo"].unique() if t])

# --- sidebar filtros ---
st.sidebar.header("Filtros")
sel_tipos   = st.sidebar.multiselect("Tipo de desarrollo", tipos_all)
sel_estilos = st.sidebar.multiselect("Estilo / diseño", estilos_all)
sel_estados = st.sidebar.multiselect("Estado del proyecto", estados_all)
sel_amen    = st.sidebar.multiselect("Amenidades", amenities_all)

col_btn1, col_btn2 = st.sidebar.columns(2)
reset = col_btn1.button("Reset filtros")
download_flag = col_btn2.button("Descargar filtrado")

if reset:
    sel_tipos.clear(); sel_estilos.clear(); sel_estados.clear(); sel_amen.clear()

# --- aplicar filtros ---
mask = pd.Series([True]*len(df))
if sel_tipos:
    mask &= df["tipo_desarrollo"].isin(sel_tipos)
if sel_estilos:
    mask &= df["diseno_estilo"].isin(sel_estilos)
if sel_estados:
    mask &= df["estado_desarrollo"].isin(sel_estados)
if sel_amen:
    # cada desarrollo debe contener TODAS las amenidades seleccionadas
    mask &= df["amenidades_tags"].apply(lambda L: all(a in L for a in sel_amen))

df_f = df[mask].copy()

# --- mapa ---
# centro: Santarena si existe; si no, promedio
if (df["nombre"].str.lower()=="santarena").any():
    centro = df.loc[df["nombre"].str.lower()=="santarena", ["lat","lon"]].iloc[0].astype(float).tolist()
else:
    centro = [df["lat"].astype(float).mean(), df["lon"].astype(float).mean()]

m = folium.Map(location=centro, zoom_start=14, tiles="OpenStreetMap")

# buffers (1km y 3km) sobre Santarena si existe
if (df["nombre"].str.lower()=="santarena").any():
    c = df.loc[df["nombre"].str.lower()=="santarena", ["lat","lon"]].iloc[0].astype(float).tolist()
    folium.Circle(location=c, radius=1000, fill=False).add_to(m)
    folium.Circle(location=c, radius=3000, fill=False).add_to(m)

cluster = MarkerCluster(name="Desarrollos").add_to(m)

def popup_html(row):
    parts = [f"<b>{row['nombre']}</b>"]
    if row["tipo_desarrollo"]: parts.append(row["tipo_desarrollo"])
    if row["tipologias_superficie_m2"]: parts.append(f"<b>Tipologías/m²:</b> {row['tipologias_superficie_m2']}")
    if row["amenidades"]: parts.append(f"<b>Amenidades:</b> {row['amenidades']}")
    if row["estado_desarrollo"]: parts.append(f"<b>Estado:</b> {row['estado_desarrollo']}")
    if row["website"]: parts.append(f"<a href='{row['website']}' target='_blank'>Sitio web</a>")
    return "<br>".join(parts)

for _, r in df_f.iterrows():
    try:
        lat, lon = float(r["lat"]), float(r["lon"])
    except:
        continue
    color = "red" if str(r["nombre"]).strip().lower()=="santarena" else "blue"
    folium.Marker(
        [lat, lon],
        tooltip=r["nombre"],
        popup=popup_html(r),
        icon=folium.Icon(color=color, icon="info-sign"),
    ).add_to(cluster)

folium.LayerControl(collapsed=False).add_to(m)

# render en Streamlit
st.markdown("### Mapa de competencia — Los Cabos")
st.caption(f"{len(df_f)} de {len(df)} desarrollos coinciden con los filtros.")
st.components.v1.html(m._repr_html_(), height=650, scrolling=False)

# descarga CSV filtrado
if download_flag:
    csv_buf = StringIO()
    df_f.drop(columns=["amenidades_tags"], errors="ignore").to_csv(csv_buf, index=False, encoding="utf-8-sig")
    st.download_button("Descargar CSV filtrado", data=csv_buf.getvalue(), file_name="competencia_filtrado.csv", mime="text/csv")
# Out:
# 2025-08-11 22:58:26.026 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.039 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.150
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/danib/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-08-11 22:58:26.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-11 22:58:26.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
